# %% [markdown]
# ## MLFlow Tracking Server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment('check connection')

with mlflow.start_run():
    mlflow.log_metric('test1',1)
    mlflow.log_metric('test2',2)
# Out:
# 2025/07/28 11:37:34 INFO mlflow.tracking.fluent: Experiment with name 'check connection' does not exist. Creating a new experiment.
# 🏃 View run vaunted-snail-723 at: http://127.0.0.1:5000/#/experiments/411919203296206978/runs/f375168b031d40d38d84a71c35555829
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/411919203296206978

# %%
mlflow.set_experiment('check connection')

with mlflow.start_run():
    mlflow.log_metric('test1',1)
    mlflow.log_metric('test2',3)
# Out:
# 🏃 View run fortunate-croc-98 at: http://127.0.0.1:5000/#/experiments/411919203296206978/runs/97e23d407b1949e99449bc8523fc8b77
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/411919203296206978
